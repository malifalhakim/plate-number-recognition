# %% [markdown]
# ### Clone Repository and Download Pretrain

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git

# %%
# %cd /content/drive/MyDrive/PaddleOCR

# %%
# # Download the pre-trained model of en_PP-OCRv3
#!wget -P ./pretrain_models/ https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_rec_train.tar
# Decompress model parameters
#%cd pretrain_models
#!tar -xf en_PP-OCRv3_rec_train.tar && rm -rf en_PP-OCRv3_rec_train.tar
#%cd ..

# Note: Do in google colab

# %% [markdown]
# Download folder PaddleOCR dari google colab dan pindahkan ke local agar dapat dijalankan di local

# %% [markdown]
# ### Install Dependencies

# %%
# !pip install paddlepaddle paddleocr

# %%
# !pip install -r requirements.txt # Jangan lupa masuk ke folder paddleocr

# %%
# !pip install paddlepaddle-gpu

# %% [markdown]
# ### Check is Running with GPU

# %%
# import torch
# torch.cuda.is_available()
# Out:
# True

# %%
# import paddle
# paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %% [markdown]
# ### Training

# %%
# !python tools/train.py -c configs/rec/PP-OCRv3/en_PP-OCRv3_rec.yml -o Global.pretrained_model=./pretrain_models/en_PP-OCRv3_rec_train/best_accuracy
# Out:
# /usr/local/lib/python3.10/dist-packages/paddle/fluid/framework.py:549: UserWarning: You are using GPU version Paddle, but your CUDA device is not set properly. CPU device will be used by default.
#   warnings.warn(
# E0704 14:07:47.323925 29400 place.cc:332] Cannot use GPU because there is no GPU detected on your machine.

# %% [markdown]
# Continue Training

# %%
# !python3 tools/train.py -c configs/rec/PP-OCRv3/en_PP-OCRv3_rec.yml -o Global.checkpoints=./output/v3_en_mobile/latest
# Out:
# [2023/07/05 06:48:55] ppocr INFO: Architecture :
# [2023/07/05 06:48:56] ppocr INFO:     Backbone :
# [2023/07/05 06:48:56] ppocr INFO:         last_conv_stride : [1, 2]
# [2023/07/05 06:48:56] ppocr INFO:         last_pool_type : avg
# [2023/07/05 06:48:56] ppocr INFO:         name : MobileNetV1Enhance
# [2023/07/05 06:48:56] ppocr INFO:         scale : 0.5
# [2023/07/05 06:48:56] ppocr INFO:     Head :
# [2023/07/05 06:48:56] ppocr INFO:         head_list :
# [2023/07/05 06:48:56] ppocr INFO:             CTCHead :
# [2023/07/05 06:48:56] ppocr INFO:                 Head :
# [2023/07/05 06:48:56] ppocr INFO:                     fc_decay : 1e-05
# [2023/07/05 06:48:56] ppocr INFO:                 Neck :
# [2023/07/05 06:48:56] ppocr INFO:                     depth : 2
# [2023/07/05 06:48:56] ppocr INFO:                     dims : 64
# [2023/07/05 06:48:56] ppocr INFO:                     hidden_dims : 120
# [2023/07/05 06:48:56] ppocr INFO:                     name : svtr
# ...

# %% [markdown]
# ### Evaluation

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv3/en_PP-OCRv3_rec.yml -o Global.checkpoints=./output/v3_en_mobile/iter_epoch_201

# %% [markdown]
# ### Predict Test Dataset

# %%
# !python tools/infer_rec.py -c configs/rec/PP-OCRv3/en_PP-OCRv3_rec.yml -o Global.pretrained_model=./output/v3_en_mobile/iter_epoch_201  Global.infer_img=./Dataset/Test
